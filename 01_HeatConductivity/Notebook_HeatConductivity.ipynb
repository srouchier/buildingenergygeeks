# %% [markdown]
# # 01_HeatConductivity
# ## Identifying the heat conductivity of a wall with Bayesian Inference
#
# This page is a tutorial on Bayesian inference applied to the characterisation of the thermal conductivity of a wall under uncertainty, using the [pymc](http://pymc-devs.github.io/pymc/) python library.
#
# This is not an introduction to Bayesian inference or to its python implementation pymc. There is a lot of online material on these topics, and I advise [this great book](http://camdavidsonpilon.github.io/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/) if you are getting started into Bayesian statistics for non-mathematicians. This guide is more of an example case on how to integrate grey-box or black-box function evaluations into the inference algorithm.
#
# ## 1. Introduction
#
# Consider the classic Inverse Heat Conduction Problem (IHCP) illustrated here:

# %%
from IPython.display import Image
Image(filename='figures/IHCP.png', width = 240)

# %% [markdown]
# The problem is one-dimensional heat conduction inside a wall of thermal conductivity $k$. One boundary is subjected to a heat flow $u$ while the other boundary is either insulated ($h=0$) or open ($h>0$). A temperature sensor is placed at a certain location $x_c$ within the medium. The initial temperature is uniform $T_0 = 0^{\circ}C$.
#
# A very usual form of sollicitation (heat flow), and its resulting temperature profile in the middle of the wall, in the case of an insulated wall ($h=0$), may look like this:

# %%
Image(filename='figures/input_output.png', width = 600)

# %% [markdown]
# Note that the data is noisy, which is essential in any interesting tutorial on inverse methods (we will get back to that below).
#
# In the standard IHCP, the boundary heat flow is unknown and the target is to reconstruct it from the temperature records. The heat conductivity, sensor position and convection coefficient are known assumptions of the problem. The present tutorial however shows another alternative of the IHCP: the heat flow and the temperature are known, and the target is to characterise the thermal conductivity of the material. In order to make things a bit more complicated (and therefore interesting), we are considering **4 unknowns**:
# * the thermal conductivity $k$, of course;
# * the sensor position $x_s$ is known *a priori*, but may be a bit uncertain: let's include it in the inference;
# * some white noise is included in the measurements of the heat flow and temperature. We can estimate the standard deviations of the noise components, respectively denoted $\sigma^u$ and $\sigma^T$.
#
# The problem can be summarised in the following Bayesian network (this sketch was drawn using the using the [daft](http://daft-pgm.org/) python library):

# %%
Image(filename = 'figures/drawing_tree_conductivity.png', width = 250)

# %% [markdown]
# This network can be read from top to bottom as follows:
# * The **real** heat flow $u$ is unknown: its parents are the observed heat flow $u^\mathrm{obs}$ and the standard deviation of its white noise component $\sigma^u$.
# * The **real** temperature at the sensor position is unknown. It is entirely defined by the real heat flow, the sensor position and the thermal conductivity, all of which are unknown.
# * The **observed** temperature $T^\mathrm{obs}$ is not the real one: we must account for some measurement noise of standard deviation $\sigma^T$.
#
# All initially available data is contained within the fixed parent variable $u^\mathrm{obs}$ and the final child variable $T^\mathrm{obs}$, neither of which is exactly equal to the real physical value of the heat flow or the temperature. The outcome of the inference are the parent nodes shown in red.
#
# This is where some of the potential of Bayesian inference can be illustrated: any value can be considered unknown, and the effect of all prior uncertainties on the outcome can be estimated. For instance, supposing a certain structure for the noise, we can include it in the inference model structure and see its effects on the uncertainty of the final results of the identification. This is done here in the simple case of white noise, but the possibility for additional sources of uncertainty may be added, such as a systematic measurement error on a sensor. Second example: in order to show that we are not entirely sure of the exact position of the temperature sensor within the wall, this position may be added as an uncertain value with a more or less narrow prior distribution. This means that the sensor position should be explicitely used as a parameter when calling the deterministic function for temperature calculation (see below).

# %% [markdown]
# ## 2. Code for the inference
#
# All file used within this tutorial are available in the `InverseBuilding` repository that you can clone or download. This example is located within the `'InverseBuilding/wall/thermal'` folder.
#
# ### Setting up the network
#
# Let's start by saving the true value of the unknown parameters. This will be the reference for judging the accuracy of the identification.

# %%
xs_true       = 0.05 / 2  # sensor position
k_true        = 0.3       # thermal conductivity
sigma_T_true  = 0.2       # temperature noise
sigma_u_true  = 10        # heat flow noise

# %% [markdown]
# Next, we import measurement data for the heat flow and temperature, and add white noise to make it slightly more realistic. This is where we use the real values of $\sigma^T$ and $\sigma^u$. The following lines read the ideal heat and temperature profiles within the text file, and adds a normal random component of zero mean and known deviation.

# %%
import numpy as np
import pandas

data_file = pandas.read_csv('inputs.txt', delimiter='\t')
time_file = data_file['t (s)']

u_file    = np.array( data_file['U (W/m2)'] )
u_file   += np.random.normal(0, sigma_u_true, size=np.size(u_file))
T_file    = np.array( data_file['T(e/2)'] )
T_file   += np.random.normal(0, sigma_T_true, size=np.size(T_file))

# %% [markdown]
# Next, we define the prior probability distributions for each of the 4 unknowns. This is where the first call to the [pymc](http://pymc-devs.github.io/pymc/) module occurs, so it obviously has to be installed first (see the package's repository and website for help).
#
# The prior probability distribution of a variable indicates in what range we *believe* its value is. This is where the subjective part of the work occurs, since Bayesian inference relies on expert knowledge as much as on objective sensor data. Choosing a good prior is not always trivial, and I do not aim at giving guidelines on how to do it. The basic requirements are that we should integrate as much expert knowledge as possible in order to put some constraints on the search space, without compromising the chances of any possible solution.
#
# Three types of probability distributions are used here:
# * we only have a vague idea of the possible range of $k$ and $\sigma^u$: let's start with **uniform** distributions for them;
# * we are quite certain of the sensor position $x_s$, but it might be a bit off: a **normal** distribution seems a good choice;
# * the temperature noise $\sigma^T$ is probably low, but it *might* be higher than we expect: an **exponential** distribution seems right.
#
# Here is a graph of these prior distributions, compared to the true value of the parameters that we aim at getting back through the inference.

# %%
import pymc as pm

k_pm       = pm.Uniform("conductivity", 0.1, 1)
xs_pm      = pm.Normal('sensor position', 0.025, 1/0.001**2)
sigma_T_pm = pm.Exponential('temperature noise', 1.)
sigma_u_pm = pm.Uniform('heat flow noise', 0., 10.)

Image(filename = 'figures/priors.png', width = 800)

# %% [markdown]
# (note: the `'_pm'` part of the variable names is only a reminder that these variables are pymc objects)
#
# As is shown by the second row of the Bayesian network shown above, the **real** heat flow is also a stochastic variable, thus defined as a pymc `Stochastics` object. It is defined by a normal distribution, whose mean is the observed heat flow, and whose deviation is the stochastic variable $\sigma^u$. In terms of Bayesian network setup, $\sigma^u$ is a **parent variable** of $u$.

# %%
u_pm = pm.Normal('real heat flow', mu = u_file, tau = 1./sigma_u_pm**2)

# %% [markdown]
# The next step is the centre of our Bayesian network: how the **real** temperature is computed, assuming known input values for all its parent nodes $k$, $x_s$ and $u$. For purposes of clarity, the computation of $T$ (with the finite difference method) is written in a separate file `simulate_temperature.py`, from which the function is imported.
#
# Pymc sees $T$ as a *deterministic* variable: its value is entirely determined by its parent nodes. The appropriate syntax for its definition is as follows:

# %%
from simulate_temperature import T_func
@pm.deterministic
def T(k = k_pm, xs = xs_pm, u = u_pm):
    return T_func(k, xs, u, time_file)

# %% [markdown]
# But of course, the real temperature is not the one we get from measurements: the observed temperature $T^\mathrm{obs}$ is the last node of the network.

# %%
observation = pm.Normal("obs", mu = T, tau = 1./sigma_T_pm**2, value = T_file, observed=True)

# %% [markdown]
# It is essential while defining this variable that the `observed` tag is set to `True`, and that the `value` tag points to the measurements. This ensures that the observation cannot be changed during the run of the algorithm.
#
# All nodes of the network have been defined. The last step is to assemble the model:

# %%
R = pm.MCMC([k_pm, xs_pm, sigma_T_pm, sigma_u_pm])

# %% [markdown]
# ### Running the inference
#
# Our work here is done. It is now time to start the calculation and take a break while the computer does all the work. The following line starts a Markov Chain of 10 000 samples, and records the traces with a burn-in period of 5 000 and a thinning of 5. We therefore only keep 1 000 sample values for each of the inferred variables.

# %%
R.sample(10000, burn = 5000, thin = 5)
# Out:
#  [                  0%                  ] 11 of 10000 complete in 0.5 sec
#  [                  0%                  ] 19 of 10000 complete in 1.1 sec
#  [                  0%                  ] 26 of 10000 complete in 1.6 sec
#  [                  0%                  ] 44 of 10000 complete in 2.2 sec
#  [                  0%                  ] 51 of 10000 complete in 2.7 sec
#  [                  0%                  ] 57 of 10000 complete in 3.3 sec
#  [                  0%                  ] 72 of 10000 complete in 3.8 sec
#  [                  0%                  ] 86 of 10000 complete in 4.3 sec
#  [                  0%                  ] 95 of 10000 complete in 4.8 sec
#  [                  1%                  ] 102 of 10000 complete in 5.5 sec
#  [                  1%                  ] 111 of 10000 complete in 6.0 sec
#  [                  1%                  ] 121 of 10000 complete in 6.5 sec
#  [                  1%                  ] 130 of 10000 complete in 7.0 sec
#  [                  1%                  ] 143 of 10000 complete in 7.7 sec
#  [                  1%                  ] 152 of 10000 complete in 8.2 sec
#  [                  1%                  ] 165 of 10000 complete in 8.7 sec
#  [                  1%                  ] 178 of 10000 complete in 9.2 sec
#  [                  1%                  ] 187 of 10000 complete in 9.7 sec
#  [                  2%                  ] 202 of 10000 complete in 10.3 sec
#  [                  2%                  ] 219 of 10000 complete in 10.8 sec
#  [                  2%                  ] 238 of 10000 complete in 11.3 sec
#  [                  2%                  ] 252 of 10000 complete in 11.8 sec
#  [-                 2%                  ] 265 of 10000 complete in 12.3 sec
#  [-                 2%                  ] 283 of 10000 complete in 12.8 sec
#  [-                 2%                  ] 296 of 10000 complete in 13.4 sec
#  [-                 3%                  ] 304 of 10000 complete in 14.0 sec
#  [-                 3%                  ] 320 of 10000 complete in 14.5 sec
#  [-                 3%                  ] 339 of 10000 complete in 15.0 sec
#  [-                 3%                  ] 358 of 10000 complete in 15.5 sec
#  [-                 3%                  ] 371 of 10000 complete in 16.0 sec
#  [-                 3%                  ] 387 of 10000 complete in 16.5 sec
#  [-                 4%                  ] 406 of 10000 complete in 17.1 sec
#  [-                 4%                  ] 425 of 10000 complete in 17.6 sec
#  [-                 4%                  ] 443 of 10000 complete in 18.1 sec
#  [-                 4%                  ] 461 of 10000 complete in 18.6 sec
#  [-                 4%                  ] 481 of 10000 complete in 19.1 sec
#  [-                 4%                  ] 496 of 10000 complete in 19.6 sec
#  [-                 5%                  ] 513 of 10000 complete in 20.1 sec
#  [--                5%                  ] 533 of 10000 complete in 20.7 sec
#  [--                5%                  ] 554 of 10000 complete in 21.2 sec
#  [--                5%                  ] 571 of 10000 complete in 21.7 sec
#  [--                5%                  ] 591 of 10000 complete in 22.2 sec
#  [--                6%                  ] 607 of 10000 complete in 22.7 sec
#  [--                6%                  ] 623 of 10000 complete in 23.2 sec
#  [--                6%                  ] 640 of 10000 complete in 23.8 sec
#  [--                6%                  ] 656 of 10000 complete in 24.3 sec
#  [--                6%                  ] 670 of 10000 complete in 24.8 sec
#  [--                6%                  ] 685 of 10000 complete in 25.3 sec
#  [--                6%                  ] 696 of 10000 complete in 25.8 sec
#  [--                7%                  ] 715 of 10000 complete in 26.4 sec
#  [--                7%                  ] 731 of 10000 complete in 26.9 sec
#  [--                7%                  ] 748 of 10000 complete in 27.4 sec
#  [--                7%                  ] 765 of 10000 complete in 28.0 sec
#  [--                7%                  ] 771 of 10000 complete in 28.5 sec
#  [--                7%                  ] 784 of 10000 complete in 29.0 sec
#  [---               8%                  ] 804 of 10000 complete in 29.6 sec
#  [---               8%                  ] 822 of 10000 complete in 30.1 sec
#  [---               8%                  ] 837 of 10000 complete in 30.6 sec
#  [---               8%                  ] 860 of 10000 complete in 31.1 sec
#  [---               8%                  ] 874 of 10000 complete in 31.6 sec
#  [---               8%                  ] 887 of 10000 complete in 32.1 sec
#  [---               8%                  ] 898 of 10000 complete in 32.7 sec
#  [---               9%                  ] 915 of 10000 complete in 33.3 sec
#  [---               9%                  ] 923 of 10000 complete in 33.8 sec
#  [---               9%                  ] 941 of 10000 complete in 34.3 sec
#  [---               9%                  ] 959 of 10000 complete in 34.8 sec
#  [---               9%                  ] 977 of 10000 complete in 35.3 sec
#  [---               9%                  ] 994 of 10000 complete in 35.8 sec
#  [---              10%                  ] 1012 of 10000 complete in 36.3 sec
#  [---              10%                  ] 1029 of 10000 complete in 36.8 sec
#  [---              10%                  ] 1044 of 10000 complete in 37.4 sec
#  [----             10%                  ] 1059 of 10000 complete in 37.9 sec
#  [----             10%                  ] 1074 of 10000 complete in 38.4 sec
#  [----             10%                  ] 1088 of 10000 complete in 38.9 sec
#  [----             11%                  ] 1107 of 10000 complete in 39.4 sec
#  [----             11%                  ] 1124 of 10000 complete in 40.0 sec
#  [----             11%                  ] 1142 of 10000 complete in 40.5 sec
#  [----             11%                  ] 1161 of 10000 complete in 41.0 sec
#  [----             11%                  ] 1174 of 10000 complete in 41.5 sec
#  [----             11%                  ] 1191 of 10000 complete in 42.0 sec
#  [----             12%                  ] 1207 of 10000 complete in 42.5 sec
#  [----             12%                  ] 1223 of 10000 complete in 43.0 sec
#  [----             12%                  ] 1238 of 10000 complete in 43.6 sec
#  [----             12%                  ] 1254 of 10000 complete in 44.1 sec
#  [----             12%                  ] 1267 of 10000 complete in 44.6 sec
#  [----             12%                  ] 1279 of 10000 complete in 45.1 sec
#  [----             12%                  ] 1297 of 10000 complete in 45.6 sec
#  [----             13%                  ] 1314 of 10000 complete in 46.1 sec
#  [-----            13%                  ] 1330 of 10000 complete in 46.6 sec
#  [-----            13%                  ] 1346 of 10000 complete in 47.1 sec
#  [-----            13%                  ] 1360 of 10000 complete in 47.6 sec
#  [-----            13%                  ] 1375 of 10000 complete in 48.1 sec
#  [-----            13%                  ] 1389 of 10000 complete in 48.6 sec
#  [-----            14%                  ] 1404 of 10000 complete in 49.1 sec
#  [-----            14%                  ] 1417 of 10000 complete in 49.6 sec
#  [-----            14%                  ] 1433 of 10000 complete in 50.2 sec
#  [-----            14%                  ] 1452 of 10000 complete in 50.7 sec
#  [-----            14%                  ] 1465 of 10000 complete in 51.2 sec
#  [-----            14%                  ] 1481 of 10000 complete in 51.7 sec
#  [-----            15%                  ] 1501 of 10000 complete in 52.2 sec
#  [-----            15%                  ] 1520 of 10000 complete in 52.7 sec
#  [-----            15%                  ] 1539 of 10000 complete in 53.2 sec
#  [-----            15%                  ] 1557 of 10000 complete in 53.7 sec
#  [-----            15%                  ] 1572 of 10000 complete in 54.3 sec
#  [------           15%                  ] 1590 of 10000 complete in 54.8 sec
#  [------           16%                  ] 1608 of 10000 complete in 55.3 sec
#  [------           16%                  ] 1627 of 10000 complete in 55.8 sec
#  [------           16%                  ] 1644 of 10000 complete in 56.4 sec
#  [------           16%                  ] 1662 of 10000 complete in 56.9 sec
#  [------           16%                  ] 1679 of 10000 complete in 57.4 sec
#  [------           16%                  ] 1696 of 10000 complete in 57.9 sec
#  [------           17%                  ] 1713 of 10000 complete in 58.4 sec
#  [------           17%                  ] 1732 of 10000 complete in 58.9 sec
#  [------           17%                  ] 1747 of 10000 complete in 59.5 sec
#  [------           17%                  ] 1763 of 10000 complete in 60.0 sec
#  [------           17%                  ] 1780 of 10000 complete in 60.5 sec
#  [------           17%                  ] 1795 of 10000 complete in 61.0 sec
#  [------           18%                  ] 1812 of 10000 complete in 61.5 sec
#  [------           18%                  ] 1828 of 10000 complete in 62.0 sec
#  [-------          18%                  ] 1845 of 10000 complete in 62.5 sec
#  [-------          18%                  ] 1859 of 10000 complete in 63.1 sec
#  [-------          18%                  ] 1876 of 10000 complete in 63.6 sec
#  [-------          18%                  ] 1891 of 10000 complete in 64.1 sec
#  [-------          19%                  ] 1910 of 10000 complete in 64.6 sec
#  [-------          19%                  ] 1926 of 10000 complete in 65.1 sec
#  [-------          19%                  ] 1943 of 10000 complete in 65.7 sec
#  [-------          19%                  ] 1957 of 10000 complete in 66.2 sec
#  [-------          19%                  ] 1973 of 10000 complete in 66.7 sec
#  [-------          19%                  ] 1990 of 10000 complete in 67.2 sec
#  [-------          20%                  ] 2005 of 10000 complete in 67.8 sec
#  [-------          20%                  ] 2020 of 10000 complete in 68.3 sec
#  [-------          20%                  ] 2032 of 10000 complete in 68.8 sec
#  [-------          20%                  ] 2046 of 10000 complete in 69.3 sec
#  [-------          20%                  ] 2062 of 10000 complete in 69.8 sec
#  [-------          20%                  ] 2078 of 10000 complete in 70.4 sec
#  [-------          20%                  ] 2095 of 10000 complete in 70.9 sec
#  [--------         21%                  ] 2110 of 10000 complete in 71.4 sec
#  [--------         21%                  ] 2126 of 10000 complete in 72.0 sec
#  [--------         21%                  ] 2142 of 10000 complete in 72.5 sec
#  [--------         21%                  ] 2157 of 10000 complete in 73.0 sec
#  [--------         21%                  ] 2174 of 10000 complete in 73.5 sec
#  [--------         21%                  ] 2190 of 10000 complete in 74.1 sec
#  [--------         22%                  ] 2206 of 10000 complete in 74.6 sec
#  [--------         22%                  ] 2218 of 10000 complete in 75.1 sec
#  [--------         22%                  ] 2234 of 10000 complete in 75.6 sec
#  [--------         22%                  ] 2251 of 10000 complete in 76.1 sec
#  [--------         22%                  ] 2268 of 10000 complete in 76.6 sec
#  [--------         22%                  ] 2283 of 10000 complete in 77.2 sec
#  [--------         22%                  ] 2297 of 10000 complete in 77.7 sec
#  [--------         23%                  ] 2310 of 10000 complete in 78.2 sec
#  [--------         23%                  ] 2324 of 10000 complete in 78.7 sec
#  [--------         23%                  ] 2338 of 10000 complete in 79.2 sec
#  [--------         23%                  ] 2353 of 10000 complete in 79.7 sec
#  [--------         23%                  ] 2368 of 10000 complete in 80.2 sec
#  [---------        23%                  ] 2383 of 10000 complete in 80.8 sec
#  [---------        23%                  ] 2396 of 10000 complete in 81.3 sec
#  [---------        24%                  ] 2410 of 10000 complete in 81.8 sec
#  [---------        24%                  ] 2425 of 10000 complete in 82.3 sec
#  [---------        24%                  ] 2439 of 10000 complete in 82.8 sec
#  [---------        24%                  ] 2455 of 10000 complete in 83.3 sec
#  [---------        24%                  ] 2472 of 10000 complete in 83.8 sec
#  [---------        24%                  ] 2487 of 10000 complete in 84.3 sec
#  [---------        25%                  ] 2501 of 10000 complete in 84.8 sec
#  [---------        25%                  ] 2516 of 10000 complete in 85.4 sec
#  [---------        25%                  ] 2529 of 10000 complete in 85.9 sec
#  [---------        25%                  ] 2543 of 10000 complete in 86.4 sec
#  [---------        25%                  ] 2557 of 10000 complete in 86.9 sec
#  [---------        25%                  ] 2571 of 10000 complete in 87.4 sec
#  [---------        25%                  ] 2586 of 10000 complete in 87.9 sec
#  [---------        25%                  ] 2598 of 10000 complete in 88.4 sec
#  [---------        26%                  ] 2609 of 10000 complete in 89.0 sec
#  [---------        26%                  ] 2624 of 10000 complete in 89.5 sec
#  [----------       26%                  ] 2637 of 10000 complete in 90.0 sec
#  [----------       26%                  ] 2649 of 10000 complete in 90.5 sec
#  [----------       26%                  ] 2661 of 10000 complete in 91.0 sec
#  [----------       26%                  ] 2675 of 10000 complete in 91.5 sec
#  [----------       26%                  ] 2689 of 10000 complete in 92.1 sec
#  [----------       27%                  ] 2703 of 10000 complete in 92.6 sec
#  [----------       27%                  ] 2716 of 10000 complete in 93.1 sec
#  [----------       27%                  ] 2729 of 10000 complete in 93.6 sec
#  [----------       27%                  ] 2740 of 10000 complete in 94.1 sec
#  [----------       27%                  ] 2752 of 10000 complete in 94.7 sec
#  [----------       27%                  ] 2765 of 10000 complete in 95.2 sec
#  [----------       27%                  ] 2778 of 10000 complete in 95.7 sec
#  [----------       27%                  ] 2791 of 10000 complete in 96.3 sec
#  [----------       28%                  ] 2804 of 10000 complete in 96.8 sec
#  [----------       28%                  ] 2816 of 10000 complete in 97.3 sec
#  [----------       28%                  ] 2827 of 10000 complete in 97.8 sec
#  [----------       28%                  ] 2839 of 10000 complete in 98.4 sec
#  [----------       28%                  ] 2851 of 10000 complete in 98.9 sec
#  [----------       28%                  ] 2863 of 10000 complete in 99.4 sec
#  [----------       28%                  ] 2874 of 10000 complete in 99.9 sec
#  [----------       28%                  ] 2886 of 10000 complete in 100.5 sec
#  [-----------      28%                  ] 2897 of 10000 complete in 101.0 sec
#  [-----------      29%                  ] 2909 of 10000 complete in 101.5 sec
#  [-----------      29%                  ] 2920 of 10000 complete in 102.1 sec
#  [-----------      29%                  ] 2931 of 10000 complete in 102.6 sec
#  [-----------      29%                  ] 2944 of 10000 complete in 103.1 sec
#  [-----------      29%                  ] 2955 of 10000 complete in 103.6 sec
#  [-----------      29%                  ] 2969 of 10000 complete in 104.1 sec
#  [-----------      29%                  ] 2980 of 10000 complete in 104.7 sec
#  [-----------      29%                  ] 2992 of 10000 complete in 105.2 sec
#  [-----------      30%                  ] 3004 of 10000 complete in 105.7 sec
#  [-----------      30%                  ] 3016 of 10000 complete in 106.2 sec
#  [-----------      30%                  ] 3028 of 10000 complete in 106.7 sec
#  [-----------      30%                  ] 3040 of 10000 complete in 107.3 sec
#  [-----------      30%                  ] 3054 of 10000 complete in 107.8 sec
#  [-----------      30%                  ] 3065 of 10000 complete in 108.3 sec
#  [-----------      30%                  ] 3079 of 10000 complete in 108.9 sec
#  [-----------      30%                  ] 3091 of 10000 complete in 109.4 sec
#  [-----------      31%                  ] 3103 of 10000 complete in 109.9 sec
#  [-----------      31%                  ] 3117 of 10000 complete in 110.4 sec
#  [-----------      31%                  ] 3130 of 10000 complete in 110.9 sec
#  [-----------      31%                  ] 3139 of 10000 complete in 111.4 sec
#  [-----------      31%                  ] 3150 of 10000 complete in 112.0 sec
#  [------------     31%                  ] 3163 of 10000 complete in 112.5 sec
#  [------------     31%                  ] 3177 of 10000 complete in 113.0 sec
#  [------------     31%                  ] 3189 of 10000 complete in 113.5 sec
#  [------------     32%                  ] 3202 of 10000 complete in 114.0 sec
#  [------------     32%                  ] 3214 of 10000 complete in 114.5 sec
#  [------------     32%                  ] 3228 of 10000 complete in 115.0 sec
#  [------------     32%                  ] 3241 of 10000 complete in 115.5 sec
#  [------------     32%                  ] 3255 of 10000 complete in 116.1 sec
#  [------------     32%                  ] 3269 of 10000 complete in 116.6 sec
#  [------------     32%                  ] 3282 of 10000 complete in 117.1 sec
#  [------------     32%                  ] 3290 of 10000 complete in 117.6 sec
#  [------------     33%                  ] 3300 of 10000 complete in 118.1 sec
#  [------------     33%                  ] 3311 of 10000 complete in 118.7 sec
#  [------------     33%                  ] 3326 of 10000 complete in 119.2 sec
#  [------------     33%                  ] 3336 of 10000 complete in 119.7 sec
#  [------------     33%                  ] 3348 of 10000 complete in 120.2 sec
#  [------------     33%                  ] 3359 of 10000 complete in 120.8 sec
#  [------------     33%                  ] 3368 of 10000 complete in 121.3 sec
#  [------------     33%                  ] 3377 of 10000 complete in 121.8 sec
#  [------------     33%                  ] 3389 of 10000 complete in 122.3 sec
#  [------------     34%                  ] 3401 of 10000 complete in 122.9 sec
#  [------------     34%                  ] 3414 of 10000 complete in 123.4 sec
#  [-------------    34%                  ] 3427 of 10000 complete in 123.9 sec
#  [-------------    34%                  ] 3438 of 10000 complete in 124.4 sec
#  [-------------    34%                  ] 3449 of 10000 complete in 124.9 sec
#  [-------------    34%                  ] 3460 of 10000 complete in 125.4 sec
#  [-------------    34%                  ] 3472 of 10000 complete in 126.0 sec
#  [-------------    34%                  ] 3485 of 10000 complete in 126.5 sec
#  [-------------    34%                  ] 3497 of 10000 complete in 127.0 sec
#  [-------------    35%                  ] 3509 of 10000 complete in 127.5 sec
#  [-------------    35%                  ] 3521 of 10000 complete in 128.0 sec
#  [-------------    35%                  ] 3534 of 10000 complete in 128.6 sec
#  [-------------    35%                  ] 3547 of 10000 complete in 129.1 sec
#  [-------------    35%                  ] 3560 of 10000 complete in 129.6 sec
#  [-------------    35%                  ] 3573 of 10000 complete in 130.1 sec
#  [-------------    35%                  ] 3585 of 10000 complete in 130.7 sec
#  [-------------    35%                  ] 3594 of 10000 complete in 131.2 sec
#  [-------------    36%                  ] 3605 of 10000 complete in 131.7 sec
#  [-------------    36%                  ] 3616 of 10000 complete in 132.2 sec
#  [-------------    36%                  ] 3628 of 10000 complete in 132.7 sec
#  [-------------    36%                  ] 3643 of 10000 complete in 133.3 sec
#  [-------------    36%                  ] 3654 of 10000 complete in 133.8 sec
#  [-------------    36%                  ] 3667 of 10000 complete in 134.4 sec
#  [-------------    36%                  ] 3680 of 10000 complete in 134.9 sec
#  [--------------   36%                  ] 3694 of 10000 complete in 135.4 sec
#  [--------------   37%                  ] 3706 of 10000 complete in 135.9 sec
#  [--------------   37%                  ] 3718 of 10000 complete in 136.4 sec
#  [--------------   37%                  ] 3730 of 10000 complete in 137.0 sec
#  [--------------   37%                  ] 3743 of 10000 complete in 137.5 sec
#  [--------------   37%                  ] 3756 of 10000 complete in 138.0 sec
#  [--------------   37%                  ] 3768 of 10000 complete in 138.5 sec
#  [--------------   37%                  ] 3781 of 10000 complete in 139.1 sec
#  [--------------   37%                  ] 3793 of 10000 complete in 139.6 sec
#  [--------------   38%                  ] 3805 of 10000 complete in 140.1 sec
#  [--------------   38%                  ] 3818 of 10000 complete in 140.7 sec
#  [--------------   38%                  ] 3830 of 10000 complete in 141.2 sec
#  [--------------   38%                  ] 3842 of 10000 complete in 141.7 sec
#  [--------------   38%                  ] 3854 of 10000 complete in 142.3 sec
#  [--------------   38%                  ] 3866 of 10000 complete in 142.8 sec
#  [--------------   38%                  ] 3879 of 10000 complete in 143.3 sec
#  [--------------   38%                  ] 3892 of 10000 complete in 143.8 sec
#  [--------------   39%                  ] 3904 of 10000 complete in 144.4 sec
#  [--------------   39%                  ] 3917 of 10000 complete in 144.9 sec
#  [--------------   39%                  ] 3929 of 10000 complete in 145.4 sec
#  [--------------   39%                  ] 3940 of 10000 complete in 145.9 sec
#  [---------------  39%                  ] 3951 of 10000 complete in 146.4 sec
#  [---------------  39%                  ] 3964 of 10000 complete in 147.0 sec
#  [---------------  39%                  ] 3976 of 10000 complete in 147.5 sec
#  [---------------  39%                  ] 3989 of 10000 complete in 148.0 sec
#  [---------------  40%                  ] 4003 of 10000 complete in 148.5 sec
#  [---------------  40%                  ] 4018 of 10000 complete in 149.0 sec
#  [---------------  40%                  ] 4030 of 10000 complete in 149.5 sec
#  [---------------  40%                  ] 4042 of 10000 complete in 150.1 sec
#  [---------------  40%                  ] 4055 of 10000 complete in 150.6 sec
#  [---------------  40%                  ] 4067 of 10000 complete in 151.1 sec
#  [---------------  40%                  ] 4079 of 10000 complete in 151.6 sec
#  [---------------  40%                  ] 4091 of 10000 complete in 152.1 sec
#  [---------------  41%                  ] 4104 of 10000 complete in 152.7 sec
#  [---------------  41%                  ] 4117 of 10000 complete in 153.2 sec
#  [---------------  41%                  ] 4130 of 10000 complete in 153.7 sec
#  [---------------  41%                  ] 4143 of 10000 complete in 154.3 sec
#  [---------------  41%                  ] 4155 of 10000 complete in 154.8 sec
#  [---------------  41%                  ] 4167 of 10000 complete in 155.3 sec
#  [---------------  41%                  ] 4179 of 10000 complete in 155.8 sec
#  [---------------  41%                  ] 4192 of 10000 complete in 156.4 sec
#  [---------------  42%                  ] 4204 of 10000 complete in 156.9 sec
#  [---------------- 42%                  ] 4217 of 10000 complete in 157.4 sec
#  [---------------- 42%                  ] 4230 of 10000 complete in 158.0 sec
#  [---------------- 42%                  ] 4242 of 10000 complete in 158.5 sec
#  [---------------- 42%                  ] 4256 of 10000 complete in 159.0 sec
#  [---------------- 42%                  ] 4271 of 10000 complete in 159.5 sec
#  [---------------- 42%                  ] 4282 of 10000 complete in 160.1 sec
#  [---------------- 42%                  ] 4294 of 10000 complete in 160.6 sec
#  [---------------- 43%                  ] 4307 of 10000 complete in 161.1 sec
#  [---------------- 43%                  ] 4319 of 10000 complete in 161.7 sec
#  [---------------- 43%                  ] 4330 of 10000 complete in 162.2 sec
#  [---------------- 43%                  ] 4343 of 10000 complete in 162.7 sec
#  [---------------- 43%                  ] 4356 of 10000 complete in 163.2 sec
#  [---------------- 43%                  ] 4369 of 10000 complete in 163.8 sec
#  [---------------- 43%                  ] 4381 of 10000 complete in 164.3 sec
#  [---------------- 43%                  ] 4394 of 10000 complete in 164.8 sec
#  [---------------- 44%                  ] 4408 of 10000 complete in 165.3 sec
#  [---------------- 44%                  ] 4421 of 10000 complete in 165.9 sec
#  [---------------- 44%                  ] 4435 of 10000 complete in 166.4 sec
#  [---------------- 44%                  ] 4448 of 10000 complete in 166.9 sec
#  [---------------- 44%                  ] 4461 of 10000 complete in 167.4 sec
#  [-----------------44%                  ] 4477 of 10000 complete in 167.9 sec
#  [-----------------44%                  ] 4490 of 10000 complete in 168.4 sec
#  [-----------------45%                  ] 4502 of 10000 complete in 168.9 sec
#  [-----------------45%                  ] 4515 of 10000 complete in 169.5 sec
#  [-----------------45%                  ] 4529 of 10000 complete in 170.0 sec
#  [-----------------45%                  ] 4540 of 10000 complete in 170.6 sec
#  [-----------------45%                  ] 4554 of 10000 complete in 171.1 sec
#  [-----------------45%                  ] 4566 of 10000 complete in 171.6 sec
#  [-----------------45%                  ] 4580 of 10000 complete in 172.1 sec
#  [-----------------45%                  ] 4592 of 10000 complete in 172.6 sec
#  [-----------------46%                  ] 4606 of 10000 complete in 173.2 sec
#  [-----------------46%                  ] 4618 of 10000 complete in 173.7 sec
#  [-----------------46%                  ] 4632 of 10000 complete in 174.2 sec
#  [-----------------46%                  ] 4646 of 10000 complete in 174.7 sec
#  [-----------------46%                  ] 4659 of 10000 complete in 175.3 sec
#  [-----------------46%                  ] 4671 of 10000 complete in 175.8 sec
#  [-----------------46%                  ] 4684 of 10000 complete in 176.3 sec
#  [-----------------46%                  ] 4695 of 10000 complete in 176.9 sec
#  [-----------------47%                  ] 4705 of 10000 complete in 177.4 sec
#  [-----------------47%                  ] 4717 of 10000 complete in 177.9 sec
#  [-----------------47%                  ] 4729 of 10000 complete in 178.4 sec
#  [-----------------47%                  ] 4742 of 10000 complete in 178.9 sec
#  [-----------------47%                  ] 4755 of 10000 complete in 179.4 sec
#  [-----------------47%                  ] 4768 of 10000 complete in 180.0 sec
#  [-----------------47%                  ] 4780 of 10000 complete in 180.5 sec
#  [-----------------47%                  ] 4792 of 10000 complete in 181.0 sec
#  [-----------------48%                  ] 4805 of 10000 complete in 181.6 sec
#  [-----------------48%                  ] 4818 of 10000 complete in 182.1 sec
#  [-----------------48%                  ] 4831 of 10000 complete in 182.6 sec
#  [-----------------48%                  ] 4842 of 10000 complete in 183.1 sec
#  [-----------------48%                  ] 4856 of 10000 complete in 183.6 sec
#  [-----------------48%                  ] 4870 of 10000 complete in 184.2 sec
#  [-----------------48%                  ] 4884 of 10000 complete in 184.7 sec
#  [-----------------48%                  ] 4898 of 10000 complete in 185.2 sec
#  [-----------------49%                  ] 4911 of 10000 complete in 185.8 sec
#  [-----------------49%                  ] 4924 of 10000 complete in 186.3 sec
#  [-----------------49%                  ] 4937 of 10000 complete in 186.8 sec
#  [-----------------49%                  ] 4950 of 10000 complete in 187.3 sec
#  [-----------------49%                  ] 4962 of 10000 complete in 187.8 sec
#  [-----------------49%                  ] 4974 of 10000 complete in 188.4 sec
#  [-----------------49%                  ] 4988 of 10000 complete in 188.9 sec
#  [-----------------50%                  ] 5002 of 10000 complete in 189.4 sec
#  [-----------------50%                  ] 5018 of 10000 complete in 190.0 sec
#  [-----------------50%                  ] 5034 of 10000 complete in 190.5 sec
#  [-----------------50%                  ] 5044 of 10000 complete in 191.0 sec
#  [-----------------50%                  ] 5058 of 10000 complete in 191.6 sec
#  [-----------------50%                  ] 5070 of 10000 complete in 192.1 sec
#  [-----------------50%                  ] 5082 of 10000 complete in 192.6 sec
#  [-----------------50%                  ] 5095 of 10000 complete in 193.1 sec
#  [-----------------51%                  ] 5107 of 10000 complete in 193.6 sec
#  [-----------------51%                  ] 5120 of 10000 complete in 194.2 sec
#  [-----------------51%                  ] 5133 of 10000 complete in 194.7 sec
#  [-----------------51%                  ] 5146 of 10000 complete in 195.2 sec
#  [-----------------51%                  ] 5158 of 10000 complete in 195.7 sec
#  [-----------------51%                  ] 5171 of 10000 complete in 196.2 sec
#  [-----------------51%                  ] 5184 of 10000 complete in 196.8 sec
#  [-----------------51%                  ] 5197 of 10000 complete in 197.3 sec
#  [-----------------52%                  ] 5209 of 10000 complete in 197.8 sec
#  [-----------------52%                  ] 5222 of 10000 complete in 198.3 sec
#  [-----------------52%                  ] 5235 of 10000 complete in 198.8 sec
#  [-----------------52%                  ] 5249 of 10000 complete in 199.3 sec
#  [-----------------52%                  ] 5263 of 10000 complete in 199.9 sec
#  [-----------------52%                  ] 5275 of 10000 complete in 200.4 sec
#  [-----------------52%                  ] 5287 of 10000 complete in 200.9 sec
#  [-----------------52%                  ] 5299 of 10000 complete in 201.4 sec
#  [-----------------53%                  ] 5310 of 10000 complete in 201.9 sec
#  [-----------------53%                  ] 5322 of 10000 complete in 202.5 sec
#  [-----------------53%                  ] 5335 of 10000 complete in 203.0 sec
#  [-----------------53%                  ] 5348 of 10000 complete in 203.5 sec
#  [-----------------53%                  ] 5360 of 10000 complete in 204.0 sec
#  [-----------------53%                  ] 5373 of 10000 complete in 204.5 sec
#  [-----------------53%                  ] 5385 of 10000 complete in 205.1 sec
#  [-----------------53%                  ] 5398 of 10000 complete in 205.6 sec
#  [-----------------54%                  ] 5409 of 10000 complete in 206.1 sec
#  [-----------------54%                  ] 5422 of 10000 complete in 206.6 sec
#  [-----------------54%                  ] 5434 of 10000 complete in 207.2 sec
#  [-----------------54%                  ] 5447 of 10000 complete in 207.7 sec
#  [-----------------54%                  ] 5459 of 10000 complete in 208.2 sec
#  [-----------------54%                  ] 5472 of 10000 complete in 208.8 sec
#  [-----------------54%                  ] 5484 of 10000 complete in 209.3 sec
#  [-----------------54%                  ] 5496 of 10000 complete in 209.8 sec
#  [-----------------55%                  ] 5508 of 10000 complete in 210.3 sec
#  [-----------------55%                  ] 5519 of 10000 complete in 210.8 sec
#  [-----------------55%-                 ] 5533 of 10000 complete in 211.4 sec
#  [-----------------55%-                 ] 5544 of 10000 complete in 211.9 sec
#  [-----------------55%-                 ] 5556 of 10000 complete in 212.4 sec
#  [-----------------55%-                 ] 5567 of 10000 complete in 212.9 sec
#  [-----------------55%-                 ] 5579 of 10000 complete in 213.4 sec
#  [-----------------55%-                 ] 5591 of 10000 complete in 213.9 sec
#  [-----------------56%-                 ] 5603 of 10000 complete in 214.5 sec
#  [-----------------56%-                 ] 5616 of 10000 complete in 215.0 sec
#  [-----------------56%-                 ] 5628 of 10000 complete in 215.5 sec
#  [-----------------56%-                 ] 5640 of 10000 complete in 216.0 sec
#  [-----------------56%-                 ] 5652 of 10000 complete in 216.5 sec
#  [-----------------56%-                 ] 5665 of 10000 complete in 217.1 sec
#  [-----------------56%-                 ] 5678 of 10000 complete in 217.6 sec
#  [-----------------56%-                 ] 5692 of 10000 complete in 218.1 sec
#  [-----------------57%-                 ] 5703 of 10000 complete in 218.6 sec
#  [-----------------57%-                 ] 5715 of 10000 complete in 219.2 sec
#  [-----------------57%-                 ] 5727 of 10000 complete in 219.7 sec
#  [-----------------57%-                 ] 5739 of 10000 complete in 220.2 sec
#  [-----------------57%-                 ] 5752 of 10000 complete in 220.7 sec
#  [-----------------57%-                 ] 5765 of 10000 complete in 221.3 sec
#  [-----------------57%-                 ] 5778 of 10000 complete in 221.8 sec
#  [-----------------57%--                ] 5790 of 10000 complete in 222.3 sec
#  [-----------------58%--                ] 5804 of 10000 complete in 222.8 sec
#  [-----------------58%--                ] 5817 of 10000 complete in 223.3 sec
#  [-----------------58%--                ] 5829 of 10000 complete in 223.9 sec
#  [-----------------58%--                ] 5842 of 10000 complete in 224.4 sec
#  [-----------------58%--                ] 5856 of 10000 complete in 224.9 sec
#  [-----------------58%--                ] 5868 of 10000 complete in 225.4 sec
#  [-----------------58%--                ] 5880 of 10000 complete in 225.9 sec
#  [-----------------58%--                ] 5893 of 10000 complete in 226.5 sec
#  [-----------------59%--                ] 5906 of 10000 complete in 227.0 sec
#  [-----------------59%--                ] 5920 of 10000 complete in 227.5 sec
#  [-----------------59%--                ] 5933 of 10000 complete in 228.0 sec
#  [-----------------59%--                ] 5945 of 10000 complete in 228.5 sec
#  [-----------------59%--                ] 5955 of 10000 complete in 229.1 sec
#  [-----------------59%--                ] 5967 of 10000 complete in 229.6 sec
#  [-----------------59%--                ] 5981 of 10000 complete in 230.2 sec
#  [-----------------59%--                ] 5994 of 10000 complete in 230.7 sec
#  [-----------------60%--                ] 6007 of 10000 complete in 231.2 sec
#  [-----------------60%--                ] 6017 of 10000 complete in 231.7 sec
#  [-----------------60%--                ] 6029 of 10000 complete in 232.2 sec
#  [-----------------60%--                ] 6041 of 10000 complete in 232.8 sec
#  [-----------------60%---               ] 6053 of 10000 complete in 233.3 sec
#  [-----------------60%---               ] 6066 of 10000 complete in 233.8 sec
#  [-----------------60%---               ] 6080 of 10000 complete in 234.4 sec
#  [-----------------60%---               ] 6093 of 10000 complete in 234.9 sec
#  [-----------------61%---               ] 6106 of 10000 complete in 235.4 sec
#  [-----------------61%---               ] 6119 of 10000 complete in 235.9 sec
#  [-----------------61%---               ] 6131 of 10000 complete in 236.5 sec
#  [-----------------61%---               ] 6145 of 10000 complete in 237.0 sec
#  [-----------------61%---               ] 6158 of 10000 complete in 237.5 sec
#  [-----------------61%---               ] 6171 of 10000 complete in 238.0 sec
#  [-----------------61%---               ] 6184 of 10000 complete in 238.6 sec
#  [-----------------61%---               ] 6196 of 10000 complete in 239.1 sec
#  [-----------------62%---               ] 6207 of 10000 complete in 239.6 sec
#  [-----------------62%---               ] 6218 of 10000 complete in 240.1 sec
#  [-----------------62%---               ] 6231 of 10000 complete in 240.6 sec
#  [-----------------62%---               ] 6244 of 10000 complete in 241.2 sec
#  [-----------------62%---               ] 6256 of 10000 complete in 241.7 sec
#  [-----------------62%---               ] 6270 of 10000 complete in 242.2 sec
#  [-----------------62%---               ] 6283 of 10000 complete in 242.7 sec
#  [-----------------62%---               ] 6294 of 10000 complete in 243.2 sec
#  [-----------------63%---               ] 6307 of 10000 complete in 243.8 sec
#  [-----------------63%----              ] 6320 of 10000 complete in 244.3 sec
#  [-----------------63%----              ] 6333 of 10000 complete in 244.8 sec
#  [-----------------63%----              ] 6347 of 10000 complete in 245.3 sec
#  [-----------------63%----              ] 6360 of 10000 complete in 245.8 sec
#  [-----------------63%----              ] 6374 of 10000 complete in 246.4 sec
#  [-----------------63%----              ] 6387 of 10000 complete in 246.9 sec
#  [-----------------63%----              ] 6398 of 10000 complete in 247.4 sec
#  [-----------------64%----              ] 6412 of 10000 complete in 247.9 sec
#  [-----------------64%----              ] 6426 of 10000 complete in 248.5 sec
#  [-----------------64%----              ] 6439 of 10000 complete in 249.0 sec
#  [-----------------64%----              ] 6451 of 10000 complete in 249.5 sec
#  [-----------------64%----              ] 6462 of 10000 complete in 250.0 sec
#  [-----------------64%----              ] 6476 of 10000 complete in 250.6 sec
#  [-----------------64%----              ] 6488 of 10000 complete in 251.1 sec
#  [-----------------65%----              ] 6500 of 10000 complete in 251.7 sec
#  [-----------------65%----              ] 6514 of 10000 complete in 252.2 sec
#  [-----------------65%----              ] 6528 of 10000 complete in 252.7 sec
#  [-----------------65%----              ] 6540 of 10000 complete in 253.2 sec
#  [-----------------65%----              ] 6551 of 10000 complete in 253.8 sec
#  [-----------------65%----              ] 6564 of 10000 complete in 254.3 sec
#  [-----------------65%----              ] 6576 of 10000 complete in 254.8 sec
#  [-----------------65%-----             ] 6589 of 10000 complete in 255.3 sec
#  [-----------------66%-----             ] 6600 of 10000 complete in 255.8 sec
#  [-----------------66%-----             ] 6613 of 10000 complete in 256.3 sec
#  [-----------------66%-----             ] 6624 of 10000 complete in 256.8 sec
#  [-----------------66%-----             ] 6636 of 10000 complete in 257.4 sec
#  [-----------------66%-----             ] 6648 of 10000 complete in 257.9 sec
#  [-----------------66%-----             ] 6661 of 10000 complete in 258.4 sec
#  [-----------------66%-----             ] 6673 of 10000 complete in 259.0 sec
#  [-----------------66%-----             ] 6685 of 10000 complete in 259.5 sec
#  [-----------------66%-----             ] 6698 of 10000 complete in 260.0 sec
#  [-----------------67%-----             ] 6709 of 10000 complete in 260.5 sec
#  [-----------------67%-----             ] 6722 of 10000 complete in 261.1 sec
#  [-----------------67%-----             ] 6735 of 10000 complete in 261.6 sec
#  [-----------------67%-----             ] 6748 of 10000 complete in 262.1 sec
#  [-----------------67%-----             ] 6760 of 10000 complete in 262.6 sec
#  [-----------------67%-----             ] 6773 of 10000 complete in 263.1 sec
#  [-----------------67%-----             ] 6785 of 10000 complete in 263.7 sec
#  [-----------------67%-----             ] 6797 of 10000 complete in 264.2 sec
#  [-----------------68%-----             ] 6812 of 10000 complete in 264.7 sec
#  [-----------------68%-----             ] 6824 of 10000 complete in 265.2 sec
#  [-----------------68%-----             ] 6836 of 10000 complete in 265.7 sec
#  [-----------------68%------            ] 6849 of 10000 complete in 266.3 sec
#  [-----------------68%------            ] 6863 of 10000 complete in 266.8 sec
#  [-----------------68%------            ] 6875 of 10000 complete in 267.4 sec
#  [-----------------68%------            ] 6888 of 10000 complete in 267.9 sec
#  [-----------------69%------            ] 6902 of 10000 complete in 268.4 sec
#  [-----------------69%------            ] 6917 of 10000 complete in 268.9 sec
#  [-----------------69%------            ] 6930 of 10000 complete in 269.4 sec
#  [-----------------69%------            ] 6943 of 10000 complete in 270.0 sec
#  [-----------------69%------            ] 6956 of 10000 complete in 270.5 sec
#  [-----------------69%------            ] 6970 of 10000 complete in 271.0 sec
#  [-----------------69%------            ] 6983 of 10000 complete in 271.5 sec
#  [-----------------69%------            ] 6996 of 10000 complete in 272.0 sec
#  [-----------------70%------            ] 7009 of 10000 complete in 272.5 sec
#  [-----------------70%------            ] 7022 of 10000 complete in 273.0 sec
#  [-----------------70%------            ] 7036 of 10000 complete in 273.5 sec
#  [-----------------70%------            ] 7047 of 10000 complete in 274.1 sec
#  [-----------------70%------            ] 7059 of 10000 complete in 274.6 sec
#  [-----------------70%------            ] 7072 of 10000 complete in 275.1 sec
#  [-----------------70%------            ] 7084 of 10000 complete in 275.6 sec
#  [-----------------70%------            ] 7096 of 10000 complete in 276.1 sec
#  [-----------------71%-------           ] 7109 of 10000 complete in 276.7 sec
#  [-----------------71%-------           ] 7125 of 10000 complete in 277.2 sec
#  [-----------------71%-------           ] 7138 of 10000 complete in 277.7 sec
#  [-----------------71%-------           ] 7153 of 10000 complete in 278.2 sec
#  [-----------------71%-------           ] 7169 of 10000 complete in 278.8 sec
#  [-----------------71%-------           ] 7183 of 10000 complete in 279.3 sec
#  [-----------------71%-------           ] 7198 of 10000 complete in 279.8 sec
#  [-----------------72%-------           ] 7211 of 10000 complete in 280.3 sec
#  [-----------------72%-------           ] 7222 of 10000 complete in 280.8 sec
#  [-----------------72%-------           ] 7237 of 10000 complete in 281.3 sec
#  [-----------------72%-------           ] 7252 of 10000 complete in 281.9 sec
#  [-----------------72%-------           ] 7265 of 10000 complete in 282.4 sec
#  [-----------------72%-------           ] 7279 of 10000 complete in 282.9 sec
#  [-----------------72%-------           ] 7292 of 10000 complete in 283.4 sec
#  [-----------------73%-------           ] 7304 of 10000 complete in 283.9 sec
#  [-----------------73%-------           ] 7316 of 10000 complete in 284.4 sec
#  [-----------------73%-------           ] 7329 of 10000 complete in 285.0 sec
#  [-----------------73%-------           ] 7345 of 10000 complete in 285.5 sec
#  [-----------------73%-------           ] 7359 of 10000 complete in 286.1 sec
#  [-----------------73%--------          ] 7373 of 10000 complete in 286.6 sec
#  [-----------------73%--------          ] 7386 of 10000 complete in 287.1 sec
#  [-----------------73%--------          ] 7398 of 10000 complete in 287.6 sec
#  [-----------------74%--------          ] 7410 of 10000 complete in 288.1 sec
#  [-----------------74%--------          ] 7422 of 10000 complete in 288.7 sec
#  [-----------------74%--------          ] 7436 of 10000 complete in 289.2 sec
#  [-----------------74%--------          ] 7448 of 10000 complete in 289.7 sec
#  [-----------------74%--------          ] 7461 of 10000 complete in 290.2 sec
#  [-----------------74%--------          ] 7472 of 10000 complete in 290.8 sec
#  [-----------------74%--------          ] 7485 of 10000 complete in 291.3 sec
#  [-----------------74%--------          ] 7498 of 10000 complete in 291.8 sec
#  [-----------------75%--------          ] 7509 of 10000 complete in 292.3 sec
#  [-----------------75%--------          ] 7521 of 10000 complete in 292.8 sec
#  [-----------------75%--------          ] 7534 of 10000 complete in 293.3 sec
#  [-----------------75%--------          ] 7547 of 10000 complete in 293.8 sec
#  [-----------------75%--------          ] 7559 of 10000 complete in 294.4 sec
#  [-----------------75%--------          ] 7572 of 10000 complete in 294.9 sec
#  [-----------------75%--------          ] 7586 of 10000 complete in 295.5 sec
#  [-----------------75%--------          ] 7598 of 10000 complete in 296.0 sec
#  [-----------------76%--------          ] 7610 of 10000 complete in 296.6 sec
#  [-----------------76%--------          ] 7622 of 10000 complete in 297.1 sec
#  [-----------------76%---------         ] 7634 of 10000 complete in 297.6 sec
#  [-----------------76%---------         ] 7647 of 10000 complete in 298.1 sec
#  [-----------------76%---------         ] 7660 of 10000 complete in 298.7 sec
#  [-----------------76%---------         ] 7673 of 10000 complete in 299.2 sec
#  [-----------------76%---------         ] 7687 of 10000 complete in 299.7 sec
#  [-----------------76%---------         ] 7698 of 10000 complete in 300.2 sec
#  [-----------------77%---------         ] 7712 of 10000 complete in 300.7 sec
#  [-----------------77%---------         ] 7725 of 10000 complete in 301.2 sec
#  [-----------------77%---------         ] 7739 of 10000 complete in 301.8 sec
#  [-----------------77%---------         ] 7752 of 10000 complete in 302.3 sec
#  [-----------------77%---------         ] 7765 of 10000 complete in 302.8 sec
#  [-----------------77%---------         ] 7778 of 10000 complete in 303.3 sec
#  [-----------------77%---------         ] 7792 of 10000 complete in 303.8 sec
#  [-----------------78%---------         ] 7803 of 10000 complete in 304.4 sec
#  [-----------------78%---------         ] 7815 of 10000 complete in 304.9 sec
#  [-----------------78%---------         ] 7830 of 10000 complete in 305.4 sec
#  [-----------------78%---------         ] 7844 of 10000 complete in 306.0 sec
#  [-----------------78%---------         ] 7858 of 10000 complete in 306.5 sec
#  [-----------------78%---------         ] 7871 of 10000 complete in 307.0 sec
#  [-----------------78%---------         ] 7885 of 10000 complete in 307.6 sec
#  [-----------------78%----------        ] 7898 of 10000 complete in 308.1 sec
#  [-----------------79%----------        ] 7911 of 10000 complete in 308.6 sec
#  [-----------------79%----------        ] 7922 of 10000 complete in 309.1 sec
#  [-----------------79%----------        ] 7934 of 10000 complete in 309.6 sec
#  [-----------------79%----------        ] 7946 of 10000 complete in 310.1 sec
#  [-----------------79%----------        ] 7959 of 10000 complete in 310.7 sec
#  [-----------------79%----------        ] 7972 of 10000 complete in 311.2 sec
#  [-----------------79%----------        ] 7984 of 10000 complete in 311.7 sec
#  [-----------------79%----------        ] 7998 of 10000 complete in 312.2 sec
#  [-----------------80%----------        ] 8010 of 10000 complete in 312.7 sec
#  [-----------------80%----------        ] 8024 of 10000 complete in 313.3 sec
#  [-----------------80%----------        ] 8039 of 10000 complete in 313.8 sec
#  [-----------------80%----------        ] 8051 of 10000 complete in 314.3 sec
#  [-----------------80%----------        ] 8063 of 10000 complete in 314.8 sec
#  [-----------------80%----------        ] 8075 of 10000 complete in 315.4 sec
#  [-----------------80%----------        ] 8088 of 10000 complete in 315.9 sec
#  [-----------------80%----------        ] 8096 of 10000 complete in 316.4 sec
#  [-----------------81%----------        ] 8106 of 10000 complete in 316.9 sec
#  [-----------------81%----------        ] 8118 of 10000 complete in 317.5 sec
#  [-----------------81%----------        ] 8130 of 10000 complete in 318.0 sec
#  [-----------------81%----------        ] 8141 of 10000 complete in 318.5 sec
#  [-----------------81%----------        ] 8150 of 10000 complete in 319.2 sec
#  [-----------------81%-----------       ] 8160 of 10000 complete in 319.7 sec
#  [-----------------81%-----------       ] 8168 of 10000 complete in 320.3 sec
#  [-----------------81%-----------       ] 8176 of 10000 complete in 320.8 sec
#  [-----------------81%-----------       ] 8188 of 10000 complete in 321.3 sec
#  [-----------------81%-----------       ] 8199 of 10000 complete in 321.8 sec
#  [-----------------82%-----------       ] 8210 of 10000 complete in 322.3 sec
#  [-----------------82%-----------       ] 8218 of 10000 complete in 322.8 sec
#  [-----------------82%-----------       ] 8228 of 10000 complete in 323.4 sec
#  [-----------------82%-----------       ] 8239 of 10000 complete in 323.9 sec
#  [-----------------82%-----------       ] 8245 of 10000 complete in 324.4 sec
#  [-----------------82%-----------       ] 8257 of 10000 complete in 325.0 sec
#  [-----------------82%-----------       ] 8269 of 10000 complete in 325.5 sec
#  [-----------------82%-----------       ] 8277 of 10000 complete in 326.2 sec
#  [-----------------82%-----------       ] 8283 of 10000 complete in 326.7 sec
#  [-----------------82%-----------       ] 8292 of 10000 complete in 327.2 sec
#  [-----------------82%-----------       ] 8298 of 10000 complete in 327.8 sec
#  [-----------------83%-----------       ] 8304 of 10000 complete in 328.3 sec
#  [-----------------83%-----------       ] 8315 of 10000 complete in 328.8 sec
#  [-----------------83%-----------       ] 8325 of 10000 complete in 329.4 sec
#  [-----------------83%-----------       ] 8337 of 10000 complete in 329.9 sec
#  [-----------------83%-----------       ] 8349 of 10000 complete in 330.4 sec
#  [-----------------83%-----------       ] 8359 of 10000 complete in 330.9 sec
#  [-----------------83%-----------       ] 8370 of 10000 complete in 331.5 sec
#  [-----------------83%-----------       ] 8383 of 10000 complete in 332.0 sec
#  [-----------------83%-----------       ] 8395 of 10000 complete in 332.5 sec
#  [-----------------84%-----------       ] 8405 of 10000 complete in 333.0 sec
#  [-----------------84%-----------       ] 8417 of 10000 complete in 333.6 sec
#  [-----------------84%------------      ] 8429 of 10000 complete in 334.1 sec
#  [-----------------84%------------      ] 8439 of 10000 complete in 334.6 sec
#  [-----------------84%------------      ] 8451 of 10000 complete in 335.1 sec
#  [-----------------84%------------      ] 8463 of 10000 complete in 335.6 sec
#  [-----------------84%------------      ] 8475 of 10000 complete in 336.2 sec
#  [-----------------84%------------      ] 8486 of 10000 complete in 336.7 sec
#  [-----------------84%------------      ] 8496 of 10000 complete in 337.2 sec
#  [-----------------85%------------      ] 8509 of 10000 complete in 337.7 sec
#  [-----------------85%------------      ] 8522 of 10000 complete in 338.3 sec
#  [-----------------85%------------      ] 8534 of 10000 complete in 338.8 sec
#  [-----------------85%------------      ] 8546 of 10000 complete in 339.4 sec
#  [-----------------85%------------      ] 8558 of 10000 complete in 339.9 sec
#  [-----------------85%------------      ] 8570 of 10000 complete in 340.4 sec
#  [-----------------85%------------      ] 8582 of 10000 complete in 340.9 sec
#  [-----------------85%------------      ] 8594 of 10000 complete in 341.4 sec
#  [-----------------86%------------      ] 8605 of 10000 complete in 341.9 sec
#  [-----------------86%------------      ] 8617 of 10000 complete in 342.4 sec
#  [-----------------86%------------      ] 8629 of 10000 complete in 343.0 sec
#  [-----------------86%------------      ] 8641 of 10000 complete in 343.5 sec
#  [-----------------86%------------      ] 8653 of 10000 complete in 344.0 sec
#  [-----------------86%------------      ] 8665 of 10000 complete in 344.5 sec
#  [-----------------86%------------      ] 8676 of 10000 complete in 345.0 sec
#  [-----------------86%-------------     ] 8688 of 10000 complete in 345.5 sec
#  [-----------------87%-------------     ] 8701 of 10000 complete in 346.1 sec
#  [-----------------87%-------------     ] 8714 of 10000 complete in 346.6 sec
#  [-----------------87%-------------     ] 8726 of 10000 complete in 347.1 sec
#  [-----------------87%-------------     ] 8739 of 10000 complete in 347.6 sec
#  [-----------------87%-------------     ] 8751 of 10000 complete in 348.2 sec
#  [-----------------87%-------------     ] 8765 of 10000 complete in 348.7 sec
#  [-----------------87%-------------     ] 8778 of 10000 complete in 349.2 sec
#  [-----------------87%-------------     ] 8790 of 10000 complete in 349.8 sec
#  [-----------------88%-------------     ] 8803 of 10000 complete in 350.3 sec
#  [-----------------88%-------------     ] 8814 of 10000 complete in 350.8 sec
#  [-----------------88%-------------     ] 8828 of 10000 complete in 351.3 sec
#  [-----------------88%-------------     ] 8842 of 10000 complete in 351.9 sec
#  [-----------------88%-------------     ] 8854 of 10000 complete in 352.4 sec
#  [-----------------88%-------------     ] 8866 of 10000 complete in 352.9 sec
#  [-----------------88%-------------     ] 8876 of 10000 complete in 353.4 sec
#  [-----------------88%-------------     ] 8887 of 10000 complete in 354.0 sec
#  [-----------------88%-------------     ] 8899 of 10000 complete in 354.5 sec
#  [-----------------89%-------------     ] 8910 of 10000 complete in 355.0 sec
#  [-----------------89%-------------     ] 8921 of 10000 complete in 355.5 sec
#  [-----------------89%-------------     ] 8934 of 10000 complete in 356.1 sec
#  [-----------------89%-------------     ] 8947 of 10000 complete in 356.6 sec
#  [-----------------89%--------------    ] 8957 of 10000 complete in 357.1 sec
#  [-----------------89%--------------    ] 8969 of 10000 complete in 357.7 sec
#  [-----------------89%--------------    ] 8981 of 10000 complete in 358.2 sec
#  [-----------------89%--------------    ] 8994 of 10000 complete in 358.7 sec
#  [-----------------90%--------------    ] 9005 of 10000 complete in 359.2 sec
#  [-----------------90%--------------    ] 9017 of 10000 complete in 359.7 sec
#  [-----------------90%--------------    ] 9030 of 10000 complete in 360.3 sec
#  [-----------------90%--------------    ] 9042 of 10000 complete in 360.8 sec
#  [-----------------90%--------------    ] 9055 of 10000 complete in 361.3 sec
#  [-----------------90%--------------    ] 9068 of 10000 complete in 361.8 sec
#  [-----------------90%--------------    ] 9082 of 10000 complete in 362.3 sec
#  [-----------------90%--------------    ] 9094 of 10000 complete in 362.8 sec
#  [-----------------91%--------------    ] 9107 of 10000 complete in 363.4 sec
#  [-----------------91%--------------    ] 9120 of 10000 complete in 363.9 sec
#  [-----------------91%--------------    ] 9133 of 10000 complete in 364.4 sec
#  [-----------------91%--------------    ] 9144 of 10000 complete in 364.9 sec
#  [-----------------91%--------------    ] 9156 of 10000 complete in 365.4 sec
#  [-----------------91%--------------    ] 9168 of 10000 complete in 366.0 sec
#  [-----------------91%--------------    ] 9179 of 10000 complete in 366.5 sec
#  [-----------------91%--------------    ] 9191 of 10000 complete in 367.0 sec
#  [-----------------92%--------------    ] 9203 of 10000 complete in 367.5 sec
#  [-----------------92%---------------   ] 9215 of 10000 complete in 368.0 sec
#  [-----------------92%---------------   ] 9227 of 10000 complete in 368.6 sec
#  [-----------------92%---------------   ] 9239 of 10000 complete in 369.1 sec
#  [-----------------92%---------------   ] 9250 of 10000 complete in 369.6 sec
#  [-----------------92%---------------   ] 9262 of 10000 complete in 370.1 sec
#  [-----------------92%---------------   ] 9273 of 10000 complete in 370.7 sec
#  [-----------------92%---------------   ] 9285 of 10000 complete in 371.2 sec
#  [-----------------92%---------------   ] 9294 of 10000 complete in 371.7 sec
#  [-----------------93%---------------   ] 9305 of 10000 complete in 372.3 sec
#  [-----------------93%---------------   ] 9317 of 10000 complete in 372.8 sec
#  [-----------------93%---------------   ] 9329 of 10000 complete in 373.3 sec
#  [-----------------93%---------------   ] 9339 of 10000 complete in 373.8 sec
#  [-----------------93%---------------   ] 9352 of 10000 complete in 374.3 sec
#  [-----------------93%---------------   ] 9364 of 10000 complete in 374.9 sec
#  [-----------------93%---------------   ] 9375 of 10000 complete in 375.4 sec
#  [-----------------93%---------------   ] 9386 of 10000 complete in 375.9 sec
#  [-----------------93%---------------   ] 9399 of 10000 complete in 376.5 sec
#  [-----------------94%---------------   ] 9410 of 10000 complete in 377.0 sec
#  [-----------------94%---------------   ] 9421 of 10000 complete in 377.5 sec
#  [-----------------94%---------------   ] 9434 of 10000 complete in 378.0 sec
#  [-----------------94%---------------   ] 9444 of 10000 complete in 378.5 sec
#  [-----------------94%---------------   ] 9455 of 10000 complete in 379.0 sec
#  [-----------------94%---------------   ] 9466 of 10000 complete in 379.6 sec
#  [-----------------94%----------------  ] 9478 of 10000 complete in 380.1 sec
#  [-----------------94%----------------  ] 9489 of 10000 complete in 380.6 sec
#  [-----------------95%----------------  ] 9500 of 10000 complete in 381.1 sec
#  [-----------------95%----------------  ] 9512 of 10000 complete in 381.6 sec
#  [-----------------95%----------------  ] 9522 of 10000 complete in 382.1 sec
#  [-----------------95%----------------  ] 9533 of 10000 complete in 382.6 sec
#  [-----------------95%----------------  ] 9545 of 10000 complete in 383.1 sec
#  [-----------------95%----------------  ] 9558 of 10000 complete in 383.6 sec
#  [-----------------95%----------------  ] 9570 of 10000 complete in 384.2 sec
#  [-----------------95%----------------  ] 9582 of 10000 complete in 384.7 sec
#  [-----------------95%----------------  ] 9594 of 10000 complete in 385.2 sec
#  [-----------------96%----------------  ] 9607 of 10000 complete in 385.8 sec
#  [-----------------96%----------------  ] 9619 of 10000 complete in 386.3 sec
#  [-----------------96%----------------  ] 9631 of 10000 complete in 386.8 sec
#  [-----------------96%----------------  ] 9645 of 10000 complete in 387.3 sec
#  [-----------------96%----------------  ] 9657 of 10000 complete in 387.9 sec
#  [-----------------96%----------------  ] 9669 of 10000 complete in 388.4 sec
#  [-----------------96%----------------  ] 9681 of 10000 complete in 388.9 sec
#  [-----------------96%----------------  ] 9691 of 10000 complete in 389.4 sec
#  [-----------------97%----------------  ] 9701 of 10000 complete in 389.9 sec
#  [-----------------97%----------------  ] 9712 of 10000 complete in 390.4 sec
#  [-----------------97%----------------  ] 9726 of 10000 complete in 390.9 sec
#  [-----------------97%----------------- ] 9737 of 10000 complete in 391.4 sec
#  [-----------------97%----------------- ] 9748 of 10000 complete in 391.9 sec
#  [-----------------97%----------------- ] 9760 of 10000 complete in 392.4 sec
#  [-----------------97%----------------- ] 9770 of 10000 complete in 392.9 sec
#  [-----------------97%----------------- ] 9780 of 10000 complete in 393.5 sec
#  [-----------------97%----------------- ] 9792 of 10000 complete in 394.0 sec
#  [-----------------98%----------------- ] 9806 of 10000 complete in 394.5 sec
#  [-----------------98%----------------- ] 9818 of 10000 complete in 395.0 sec
#  [-----------------98%----------------- ] 9829 of 10000 complete in 395.5 sec
#  [-----------------98%----------------- ] 9843 of 10000 complete in 396.1 sec
#  [-----------------98%----------------- ] 9854 of 10000 complete in 396.6 sec
#  [-----------------98%----------------- ] 9866 of 10000 complete in 397.1 sec
#  [-----------------98%----------------- ] 9876 of 10000 complete in 397.6 sec
#  [-----------------98%----------------- ] 9886 of 10000 complete in 398.1 sec
#  [-----------------98%----------------- ] 9898 of 10000 complete in 398.7 sec
#  [-----------------99%----------------- ] 9911 of 10000 complete in 399.2 sec
#  [-----------------99%----------------- ] 9921 of 10000 complete in 399.7 sec
#  [-----------------99%----------------- ] 9933 of 10000 complete in 400.2 sec
#  [-----------------99%----------------- ] 9944 of 10000 complete in 400.8 sec
#  [-----------------99%----------------- ] 9957 of 10000 complete in 401.3 sec
#  [-----------------99%----------------- ] 9969 of 10000 complete in 401.8 sec
#  [-----------------99%----------------- ] 9982 of 10000 complete in 402.3 sec
#  [-----------------99%----------------- ] 9995 of 10000 complete in 402.8 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 403.1 sec

# %% [markdown]
# ## 3. Results
#
# ### Convergence diagnostics
#
# Because we are responsible scientists, we can't just publish our results, no matter how good they look, without first checking their validity a little. We would like to make sure that convergence has been reached for each variable in the sense of the Markov chain, i.e. that enough iterations have been made to have a fair approximation of the posterior PDFs. Pymc has [built-in diagnostics tools](https://pymc-devs.github.io/pymc/modelchecking.html) for this purpose, including this handy `plot` function:

# %%
pm.Matplot.plot(k_pm)
Image(filename = 'figures/conductivity.png', width = 600)
# Out:
# Plotting conductivity

# %% [markdown]
# This built-in `plot` function shows three graphs that we can use to assess the validity of a posterior distribution:
# * The upper left panel shows the **trace** of the parameter at hand (accounting for the burn-in and thinning that have been specified for the sampling). The trace should ideally look like noise: the graph shows whether it is the case, or if we need a longer burn-in period or additional iterations.
# * The lower left panel shows the **autocorrelation** of the trace. Should it not decrease quickly enough, additional thinning may be appropriate.
# * The right panel shows the **histogram** of the trace, aka the posterior distribution, its conditional mean and 95% confidence intervals.
#
# ### Posterior distributions
#
# If the validity of the trace is confirmed by the two left panels, then we may consider the graph on the right as representative of the **posterior distribution** of this specific variable: the inference is successful (which is not the same as saying the results are good).
#
# You may retrieve the posterior distributions of our 4 unknowns by recording their traces as such:

# %%
k_samples = R.trace('conductivity')[:]
sigma_T_samples = R.trace('temperature noise')[:]
sigma_u_samples = R.trace('heat flow noise')[:]
xc_samples = R.trace('sensor position')[:]

Image(filename = 'figures/posteriors.png', width = 800)

# %% [markdown]
# Compared to the real values of the parameters we were looking for, these distributions are substantially more precise than the initial prior distributions we started from. We can assume that the inference has been a success.
